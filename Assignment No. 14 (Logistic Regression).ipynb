# %% [markdown]
# # Assignment No. 14  (LOGISTIC REGRESSION)

# %% [markdown]
# Yogesh Sabale, Roll No. - 130

# %% [markdown]
# ## Solutions >>

# %% [markdown]
# ### 1. What is Data Science? List the differences between supervised and unsupervised learning.

# %% [raw]
# >> Data science is a study of data to extract meaningful insights for business.
# >> It is multidisciplinary approach that combines principles and by using mathematics, statistics, artificial intelligence, and computer engineering to analyze large amounts of data.
# >> This analysis helps data scientists to ask and answer questions like what happened, why it happened, what will happen, and what can be done with the results.

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ### 2. What is logistic regression?

# %% [raw]
# 1. Logistic regression is a supervised machine learning algorithm mainly used for classification tasks.
#    Therefore the outcome must be a categorical or discrete value.
#
# 2. to determine the relationship between features and the probability of a particular outcome.
#
# 3. It uses a sigmoid function(logistic function) to estimate the probability for the given class.It map the predicted values to    probabilities within a range of 0 and 1..
#
# Types : 1) Binery Classification :
#               >> Target column having only two valeus.
#               >> e.g. (1/0, True/False, Good/Bad, Yes/No)
#
#         2) Multy Class Classification :
#               >> Target column having more than two values.
#                      i) Multinominal Classification :
#                         - No order of data
#                         - eg.
#                      ii) Ordinal Classification :
#                         - Order in data
#                         - eg. (High-medium-low, Rating-1,2,3)

# %% [markdown]
# ### 3. How will you deal with the multiclass classification problem using logistic regression?

# %% [raw]
# >>A multi-class classification is a classification technique that allows us to categorize data with  more than two class         labels.
# >>Trained multi-class classifiers are able to predict labels for test data based on those that are present in training data.     One-Vs-All Classification is a method of multi-classclassification.
# >>It can be broken down by splitting up the multi-class classification problem in to multiple binary classifier models.

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ### 4. Why is logistic regression very popular/widely used?

# %% [raw]
# >>Logistic Regression is a classification algorithm that is used for analyzing a dataset in which there are one or more           independent variables that determine an outcome. The outcome is binery. You can also thinks it is a case of linear regression   when the outcome variable is a categorical.
#
# >>A Logistic Regression model is less likely to be over-fitted but it can overfit in high dimensional datasets. To avoid over-   fitting these scenarios, One may consider regularization.
#
# >>It performs well for simple datasets as well as when the data set is linearly separable.

# %% [markdown]
# ### 5. Why can’t linear regression be used instead of logistic regression for classification?

# %% [raw]
# >> 1. Distribution of error terms: The distribution of data in the case of Linear and Logistic Regression is different. It            assumes that error terms are normally distributed. But this assumption does not hold true in the case of binary                classification.
#
# >> 2. Model output: In Linear Regression, the output is continuous(or numeric) while in the case of binary classification, an        output of a continuous value does not make sense.
#
# >> 3. The variance of Residual errors: Linear Regression assumes that the variance of random errors is constant. This                 assumption is also not held in the case of Logistic Regression

# %% [markdown]
# ### 6. What is the formula for the logistic regression function?

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ### 7. What are the assumptions of logistic regression?

# %%
1. No multicollinearity : No strong correlation between independent variables 
2. Linearity : Linear relationship between independent variables and the logit of outcomes
3. Large Dataset : large sample size

# %% [markdown]
# ### 8. Why is logistic regression called regression and not classification?

# %% [raw]
#   >> It Is Termed “Regression” Because The Fundamental Techniques Are Similar To Linear Regression.
# 1. The major difference between Regression and classification problem statements is that the target variable in the Regression    is continuous whereas in classification it is categorical.
# 2. Logistic Regression is basically a supervised classification algorithm. However, the Logistic Regression builds a model just    like linear regression in order to predict the probability that a given data point belongs to the category numbered as “1”.
# 3. Logistic regression models generate predicted probabilities as any number ranging from neg to pos infinity while the            probability of an outcome can only lie between 0 to 1.

# %% [markdown]
# ### 9. Explain the general intuition behind logistic regression

# %% [raw]
# The intuition behind logistic regression is to transform the output of a linear regression which has a wider range, to a range that probability lies in, which is [0,1]. The transformation formula is Logit that maps a value to a number in the range [0,1].

# %% [markdown]
# ### 10. Explain the significance of the sigmoid function

# %% [raw]
# >>A sigmoid function is a mathematical function having a characteristic "S"-shaped curve or sigmoid curve.
# >>The sigmoid function's ability to transform any real number to 0 and 1

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ### 11. How does Gradient Descent work in Logistic Regression?

# %% [raw]
# >>Gradient descent is an iterative optimization algorithm, which finds the minimum of a differentiable function. In this         process, we try different values and update them to reach the optimal ones, minimizing the output.

# %% [markdown]
# ### 12.

# %% [markdown]
# ### 13.What are the outputs of the logistic model and the logistic function?

# %%
Logistic model outputs    >> logits (i.e. log-odds)
Logistic function outputs >> probabilities.

# %% [markdown]
# ### 14. Why can’t we use Mean Square Error (MSE) as a cost function for logistic regression?

# %% [raw]
# >> When the MSE is plotted with respect to weights(slope) of the logistic regression model, the curve obtained is not a convex     curve which makes it very difficult to find the global minimum.
#
# >> For wrong predictions log loss function is strongly panalized.

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ### 15. What is the Confusion Matrix?

# %% [raw]
# >> It is a performance evaluation tool in machine learning classification problem
# >> It compare actual target values with predicted values.

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [raw]
# True Positive(TP)   : The actual positive values got correctly predicted a positive values (1>>1)
# True Negative(TN)   : The actual negative values got correctly predicted a negative values (0>>0)
# False Positive (FP) : The actual negative values got incorrectly predicted a positive values (0>>1).....Type I Error
# False Negative (FN) : The actual positive values got incorrectly predicted a negative values (1>>0).....Type II Error

# %% [markdown]
# ### 16. How do you define a classification report?

# %% [raw]
# >> It is a performance evaluation metrics of a machine learning classification problem. It provides a better understanding of      the overall performance of our trained model
# >> It displays your model’s >> 1.precision,
#                                2.recall,
#                                3.F1 score,
#                                4.support

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ### 17. What are the false positives and false negatives?

# %% [raw]
# False Positive (FP) : The actual negative values got incorrectly predicted a positive values (0>>1).....Type I Error
# False Negative (FN) : The actual positive values got incorrectly predicted a negatice values (1>>0).....Type II Error

# %% [markdown]
# ### 18. What are the true positive rate (TPR) and true-negative rate (TNR)?

# %% [raw]
# 1. True Positive Rate (TPR/Sensitivity/Recall):
#       >> Proportion of positive class got corrrectly classified
#       >> It should be alwaysty high.
#       >> Formula : TP/(TP+FN)
#
# 2. True Negative Rate(TNR/Specificity)
#       >> Proportion of negative class got correctly classified
#       >> It should be alwyas high
#       >> Formula : TN/(TN+FP)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ### 19. What is the false-positive rate (FPR) and false-negative rate (FNR)?

# %% [raw]
# 1. False Positive Rate (FPR) :
#        >> Proportion of negative class got incorrectly classified
#        >> Lower FPR is preferable
#        >> Formula : FP/(FP+TN)
#
# 2. False Negative Rate (FNR) :
#       >> Proportion of positive class got incorrectly classified
#       >> Lower FNR is preferable
#       >> Formula : FN/(FN+TP)

# %% [markdown]
# ### 20. What are precision and recall? Explain the importance with examples?

# %% [raw]
# 1. Precision >> Precision is defined as the proportion of the predictions positive class that were actally correct.
#              >> Formula : TP/(TP+FP)
#              >> e.g Recommendation, Email Spam Filteration
#
# 2. Recall(TPR) >> Recall is defined as the proportion of actual positive class that were actually correct.
#                >> Formula : TP/(TP+FN)
#                >> e.g. Medical cases

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ### 22. What is the f1 score and Explain its importance?

# %% [raw]
# >> The F1 score is a performance metric for classification and is calculated as the harmonic mean of precision and recall
# >> Formula :2PR/(P+R)
# >> a high F1-score indicates a high value for both recall and precision. Generally, F1-score is used when we need to compare      two or more machine learning algorithms for the same data. We opt for the algorithm whose f1 score is higher.

# %% [markdown]
# ### 27. What is ROC Curve?

# %% [raw]
# >> AUC - ROC curve is a performance measurement for the classification problems at various threshold settings.
# >> The ROC curve is plotted with TPR against the FPR where TPR is on the y-axis and FPR is on the x-axis.
# >> AUC near to the 1 which means it has a good measure of separability.
