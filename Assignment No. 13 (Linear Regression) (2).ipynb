# %% [markdown]
# # Assignment No.-13 (LINEAR REGRESSION)

# %% [markdown]
# Yogesh Sabale, Roll No.: 130

# %% [markdown]
# ## Solution>>

# %% [markdown]
# ### 1. What is Linear regression?

# %% [raw]
# >> Linear regression is supervised machine learning algorithm that compute the linear relationship between one or more independent features and dependent variable.
#
# >> It is a predictive model that predicts continous values in target column
#
# >> When no of independent features is one           >> Simple or univariate Linear Regression
# >> When no of independent features is more than one >> multiple or multivariate Linear Regression
#
# >> aims to find the best-fit line that describes the relationship between dependent and independent feature.The line is        determined by minimizing the sum of the squared differences between the predicted values and the actual values.
#
# >>Linear regression is commonly used in many fields, including economics, finance, and social sciences, to analyze and predict trends in data
#
# >> It is a parametric alorithm that means it's having assumptions

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ### 2. How do you represent a simple linear regression?

# %% [raw]
# >>If a one independent variable is used to predict the value of a dependent variable
#
# >>Simple linear regression has only one x variable and one y variable. The x variable is the independent variable because it is   try to predict the dependent variable. The y variable is the dependent variable because it depends on what you try to           predict.
#
# >> Formula : y = mx + c
#                        where,  x is independent variable
#                                y is dependent variable
#                                m is slope of the line
#                                c is intersept

# %% [markdown]
# ### 3. What is multiple linear regression?

# %% [raw]
# >> If more than one independent variable is used to predict the value of a dependent variable
#
# >> Formula : y=m1x1 + m2x2 +......+ c
#                        where, x1, x2 are independent varaibles
#                               y is dependent variable
#                               m1, m2 are slope of the line
#                               c is intersept

# %% [markdown]
# ### 4. What are the assumptions of the Linear regression model?

# %% [raw]
# >> Linear Regression is a parametric approach, which means that it makes assumptions about the data for the purpose of analysis.

# %% [markdown]
# #### 1) Linearity :

# %% [raw]
# >>There needs to be a linear relationship between the dependent variable and independent variable(s).
# >> Check : 1) scatter plot
#            2) df.corr()
#            3) pair plot

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# #### 2) No Multicolinearity :

# %% [raw]
# >> Multicollinearity means high-correlation between the independent variables. Due to multicollinearity, it may difficult to       find the true relationship between the predictors and target variables. Or we can say, it is difficult to determine which       predictor variable is affecting the target variable and which is not. So, the model assumes either little or no                 multicollinearity between the features or independent variables.
#
# >> There should not be linear relation between independent variable
# >> Check :1) Heat map
#           2) VIF factor (Variance Inflation Factor)
#                   Where VIF <= 4  No multicolinearity
#                         VIF >=10 High multicolinearity

# %% [markdown]
# #### 3) Normality of residual :

# %% [raw]
# >> The mean of residuals should follow a normal distribution with a mean equal to zero or close to zero. This is done in order     to check whether the selected line is actually the line of best fit or not. If the error terms are non-normally                 distributed, suggests that there are a few unusual data points that must be studied closely to make a better model.
#
# >>check : 1) KDE, Hist Plot
#           2) Hypothesis testing : Shapiro test, KS test, Normal test
#           3) QQ Plot
#           4) Skewness of residual

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# #### 4) Homoscedasticity :

# %% [raw]
# >>The error terms must have constant variance. This phenomenon is known as Homoscedasticity.
# >> It is use to find outliers
# >> It states that the errors are equally distributed

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [raw]
# 5)Independence: The observations are independent of each other.
# 6)No endogeneity: There is no relationship between the errors and the independent variables

# %% [markdown]
# ### 5. What if these assumptions get violated?

# %% [raw]
# >>If you fit a linear model to a non-linear data set, the regression algorithm would fail to capture the trend mathematically,   thus resulting in an inefficient model. Also, this will result in erroneous predictions on an unseen data set.
#
# >>The presence of correlation in error terms drastically reduces model’s accuracy.

# %% [markdown]
# ### 6. What is the assumption of Linearity? How to check Linearity? How to Handle Linearity if it gets violated?

# %% [raw]
# >> There needs to be a linear relationship between the dependent variable and independent variable(s).
#
# >> Check : 1) scatter plot
#            2) df.corr()
#            3) pair plot
#
# >> 1. Adding a quadratic term to the model
#    2. Adding an interaction term
#    3. Log transforming a predictor
#    4. Categorizing a numeric predictor

# %% [markdown]
# ### 7. What is the assumption of homoscedasticity? How to check homoscedasticity? How to prevent heteroscedasticity?

# %% [raw]
# >> The error terms must have constant variance. This phenomenon is known as Homoscedasticity.
# >> It is use to find outliers
# >> It states that the errors are equally distributed
#
# >> Check : scatter plot
#
# >> Prevent Heteroscedasticity :  1) Log or power transformations;
#                                  2) Volatility standardization;
#                                  3) Weighted regression.

# %% [markdown]
# ### 8. What is the assumption of normality? What are the different ways to check normality? How to handle it?

# %% [raw]
# >>The mean of residuals should follow a normal distribution with a mean equal to zero or close to zero. This is done in order     to check whether the selected line is actually the line of best fit or not. If the error terms are non-normally distributed,   suggests that there are a few unusual data points that must be studied closely to make a better model.
#
# >>check : 1) KDE, Hist Plot
#           2) Hypothesis testing : Shapiro test, KS test, Normal test
#           3) QQ Plot
#           4) Skewness of residual
#
# >> How to handle?
#        -Common causes include a misspecified model, data containing outliers or influential points, and response or explanatory         variables that are skewed or have heavy tails.
#        -Remedies can include transforming the response variable or explanatory variables, adding or removing variables,                 changing the functional form or interactions of the variables, and identifying and removing/adjusting outliers.

# %% [markdown]
# ### 9. What does multicollinearity mean?

# %% [raw]
# >> Multicollinearity means high-correlation between the independent variables. Due to multicollinearity, it may difficult to       find the true relationship between the predictors and target variables. Or we can say, it is difficult to determine which       predictor variable is affecting the target variable and which is not. So, the model assumes either little or no                 multicollinearity between the features or independent variables.
#
# >>There should not be linear relation between independent variable

# %% [markdown]
# ### 10.How to check Multicollinearity?

# %% [raw]
# >>Variance Inflation Factor(VIF).
#         In VIF method, we pick each feature and regress it against all of the other features. For each regression, the factor is calculated as :
#             VIF=1/(1-R^2)
#                     Where, R-squared is the coefficient of determination in linear regression. Its value lies between 0 and 1.
#
# >>We can identify highly correlated features using scatter plots or heatmap.

# %% [markdown]
# ### 11. What is VIF? What is the best value of VIF?

# %% [raw]
# >>Variance Inflation Factor(VIF).
#         1)In VIF method, we pick each feature and regress it against all of the other features. For each regression, the factor is calculated as :
#             VIF=1/(1-R^2)
#                     Where, R-squared is the coefficient of determination in linear regression. Its value lies between 0 and 1.
#
#         2)VIF factor (Variance Inflation Factor)
#                 -VIF starts at 1 and has no upper limit
#                 -VIF = 1, no correlation between the independent variable and the other variables
#                 -VIF exceeding 5 or 10 indicates high multicollinearity between this independent variable and the others

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ### 12.What are the feature selection methods in Linear Regression?

# %% [raw]
# >> Selecting the best features out of all the features to increase the model performance, as the irrelevant features decrease     the model performance of the machine learning or deep learning model.
#
# 1)Filter Methods:
#     -Select features based on statistical measures such as correlation or chi-squared test.
#     -These methods are faster and less computationally expensive than wrapper methods. When dealing with high-dimensional data,      it is computationally cheaper to use filter methods.
#         For example- Correlation-based Feature Selection, chi2 test, SelectKBest, and ANOVA F-value.
#
# 2)Wrapper Methods:
#      -Select features by evaluating their combinations using a predictive model.
#         For example- Recursive Feature Elimination, Backward Feature Elimination, Forward Feature Selection
#
# 3)Embedded Methods:
#      -Select features by learning their importance during model training.
#         For example- Lasso Regression, Ridge Regression, and Random Forest.
#
# 4)Hybrid Methods:
#      -Combine the strengths of filter and wrapper methods.
#         For Example- SelectFromModel
#
# 5)Dimensionality Reduction Techniques:
#      - Reduce the dimensionality of the dataset and select the most important features.
#         For Example- pca, lda, and ica.

# %% [markdown]
# ### 13.What is feature scaling? Is it required in Linear Regression?

# %% [raw]
# >>Feature scaling is a data preprocessing technique used to transform the values of features or variables in a dataset to a similar scale. The purpose is to ensure that all features contribute equally to the model and to avoid the domination of features with larger values.
#
# >> It is optional for Linear Regression, but it is mandatory to distance based algorithms like KNN, Kmean, PCA(Principal Compound Analysis)
#
# There are Two common techniues of feature scaling :
# 1) Normalization : Normalization helps in scaling the input features to a fixed range, typically [0, 1], to ensure that no single feature disproportionately impacts the results.
#
# 2) Standardization :Standardization ensures algorithmic stability and prevents sensitivity to the scale of input features, improves optimization algorithms’ convergence and search efficiency, and enhances the performance of certain machine learning algorithms.

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ### 14.How to find the best fit line in a linear regression model?

# %% [raw]
# Mathematically, the best fit line is obtained by minimizing the Residual Sum of Squares(RSS).
# The more precise method involves the least squares method. This is a statistical procedure to find the best fit for a set of data points by minimizing the sum of the residuals of points from the plotted curve. This is the primary technique used in regression analysis.

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ### 15.Why do we square the error instead of using modulus?

# %% [raw]
# >> The absolute error is often closer to what we want when making predictions from our model. But, if we want to penalize those predictions that are contributing to the maximum value of error.
#
# >> The squared function is differentiable everywhere, while the absolute error is not differentiable at all the points in its domain(its derivative is undefined at 0). This makes the squared error more preferable to the techniques of mathematical optimization.

# %% [markdown]
# ### 16.What techniques are adopted to find the slope and intercept of the linear regression line of the model?

# %% [raw]
# 1) Ordinary Least Squares Method (OLS) - Statistical
#     Limitation - OLS is computationally too expensive. It performs well with small data.
#                - For larger data Gradient Descent is preferred.
#
# 2) Gradient Descent Algorithm - Calculus

# %% [markdown]
# ### 17.What is the cost Function in Linear Regression?

# %% [raw]
# >> While dealing with Linear Regression we can have multiple lines for different values of slopes and intercepts. But which        line is to select which represent the right relationship between the X and Y an in order to find that we can use Mean          Squared Error (MSE) and For Linear Regression MSE is nothing but the cost function.
#
# >> Mean Squared Error is the sum of the squared differences between the prediction and true value
# >> So the line with the minimum cost function or MSE represents the relationship between X and Y in the best possible manner.

# %% [markdown]
# ### 18.Briefly explain the gradient descent algorithm

# %% [raw]
# >> Gradient Descent is one of the optimization algorithms that optimize the cost function. To find the optimum solution we need    to reduce the cost function(MSE) for all data points. This is done by updating the values of m and c iteratively until we      get an optimal solution.

# %% [markdown]
# ![image-3.png](attachment:image-3.png)

# %% [raw]
# Step-1: Gradient Descent starts with a random solution,
#            y=mx + c
#
# Step-2: Based on the direction of the gradient, the solution is updated to the new value where the cost function has a lower value.
#             New(m) = Old(m) - Alpha(Learning Rate) * Slope
#             New(c) = Old(c) - Alpha(Learning Rate) * Slope
#                       Where Slope is a partial derivatives of MSE with respect to m and c
#                       Hyoerparameter tuning is used in python to decide the value of alpha
#
#            y = New(m)x + New(c)

# %% [markdown]
# ### 19. How to evaluate regression models?

# %% [raw]
# There are five metrics used to evaluate regression models:
#     1. Mean Absolute Error(MAE)
#     2. Mean Squared Error(MSE)
#     3. Root Mean Squared Error(RMSE)
#     4. R-Squared R2 Score (Coefficient of Determination)
#     5. Adjusted R-Squared

# %% [markdown]
# ### 20. Which evaluation technique should you prefer to use for data with many outliers in it?

# %% [raw]
# >>Mean Absolute Error(MAE) is preferable to use for data having too many outliers in it because MAE is robust to outliers         whereas MSE and RMSE are very susceptible to outliers and starts penalizing the outliers by squaring the residuals.

# %% [markdown]
# ### 21.What is residual? How is it computed?

# %% [raw]
# >>Residual is also called Error. It is the difference between the predicted y value and the actual y value.
#
# >>Residual = Actual y value – Predicted y value.
#
# It can be positive or negative.
# If residuals are always 0, then your model has a Perfect R square i.e. 1.

# %% [markdown]
# ### 22.What are SSE, SSR, and SST? and What is the relationship between them?

# %% [raw]
# >>Sum of Square Error (SSE): Sum of Square Error or Sum of Square Residual Error is the sum of the squared difference between the actual value and the predicted value. It is also termed as Residual Sum of Squares.
#                 SSE =sum(Y actual - YPred)^2
#
# >>Sum of Square Regression (SSR): Sum of Square Regression is the sum of the squared difference between the predicted value and the mean of actual values. It is also termed as Explained Sum of Squares (ESS)
#                 SSR =sum(Ypred - Ymean)^2
#
# >>Sum of Square Total (SST): Sum of Squares Total is equal to the sum of the squared difference between actual values related to the response variable and the mean of actual values.
#                 SST = SSR + SSE

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ### 23.What’s the intuition behind R-Squared?

# %% [raw]
# >> R-squared Value / R2 Score / Coefficient of Determination
#
# >> R-squared is a measure of how good is the regression or best-fit line. It is also termed as the coefficient of                 determination. Mathematically, it is represented as the ratio of Sum of Squares Regression (SSR) and Sum of Squares Total       (SST).
#     R-Squared = SSR / SST
#               = (SST – SSE) / SST
#               = 1 – (SSE / SST)
#
# >> The greater the value of R-Squared, the better the regression line as higher is the variation explained by the regression line.
# >> Statistical measure of goodness of fit for a linear regression model.
# >> R-squared represents how close the prediction is to the actual value.
#
# R-squared Range   : 0 to 1
# If R-squared = 1  : Good Score, All points lies on the BFL
#    R-squared = 0  : Bad Score, All points are far away from BFL

# %% [markdown]
# ### 24.What does the coefficient of determination explain?

# %% [raw]
# >>R-squared Value / R2 Score / Coefficient of Determination
#
# >>R-squared is a measure of how good is the regression or best-fit line. It is also termed as the coefficient of determination. Mathematically, it is represented as the ratio of Sum of Squares Regression (SSR) and Sum of Squares Total (SST).
#     R-Squared = SSR / SST
#               = (SST – SSE) / SST
#               = 1 – (SSE / SST)
#
# >>The greater the value of R-Squared, the better the regression line as higher is the variation explained by the regression line.
# >>Statistical measure of goodness of fit for a linear regression model.
# >>R-squared represents how close the prediction is to the actual value.
#
# R-squared Range   : 0 to 1
# If R-squared = 1  : Good Score, All points lies on the BFL
#    R-squared = 0  : Bad Score, All points are far away from BFL

# %% [markdown]
# ### 25.Can R² be negative?

# %% [raw]
# Yes, R² can be negative. If the sum of squared error (SSE) is greater than the Sum of Squares Total(SST),(SSE>SST) R squared will be negative.
#                         (SSE>SST)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ### 26.What are the flaws in R-squared?

# %% [raw]
# >> As we are adding more and more independent variables, R² always increases irrespective of the impact of the predictor on the model. As R² always increases and never decreases, it can always appear to be a better fit with the more independent variables.
#
# >> Similarly, if our model has too many independent variables and too many high-order polynomials, we can also face the problem of over-fitting the data. Whenever the data is over-fitted, it can lead to a misleadingly high R² value which eventually can lead to misleading predictions.

# %% [markdown]
# ### 27.What is adjusted R²?

# %% [raw]
# >> Adjusted R-squared is a statistical measure used to evaluate the goodness of fit of a regression model.
# >> The advantage of Adjusted R-squared is that it penalizes the inclusion of unnecessary variables. This means that as you add more predictors to the model, the Adjusted R-squared value will only increase if the new variables significantly improve the model’s performance.

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [raw]
# Where,  n represents the number of data points in our dataset
#         k represents the number of independent variables, and
#         R represents the R-squared values determined by the model.

# %% [markdown]
# ### 28.What is the Coefficient of Correlation: Definition, Formula

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ### 29.What are the best values for correlation?

# %% [raw]
# r = 0 >>> No Linear relationship
#
# r = +1  >>> Perfect +ve linear relationship
# r = -1  >>> Perfect -ve linear relationship
#
# r = 0 to +3    >>> Weak +ve linear relationship
# r = 0 to -3    >>> Weak -ve linear relationship
#
# r = +3 to +7   >>> Moderate +ve linear relationship
# r = -3 to -7   >>> Moderate -ve linear relationship
#
# Best Values :
# r = +7 to +1   >>> Strong +ve linear relationship
# r = -7 to -1   >>> Strong -ve linear relationship

# %% [markdown]
# ![image-2.png](attachment:image-2.png)

# %% [markdown]
# ### 30.What is the difference between Correlation and covariance?

# %% [markdown]
# ![image-2.png](attachment:image-2.png)

# %% [markdown]
# ### 31.What is the relationship between R-Squared and Adjusted R-Squared?

# %% [raw]
# >>R-squared (R2) and adjusted R-squared are both used to evaluate the goodness of fit of a regression model.
# >>R2 represents the proportion of the variance in the dependent variable explained by the independent variables. Adjusted R-squared considers the number of predictors in the model and penalizes excessive variables, providing a more accurate measure of the model’s goodness of fit, especially with multiple predictors.

# %% [markdown]
# ### 32.What is the difference between overfitting and underfitting?

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ### 33.How to identify if the model is overfitted or under fitted? Explain in terms of Bias and Variance

# %% [raw]
# > A model having low bias and high variance will overfit the target,
# > A model having high bias and low variance will underfit the target.
#
# Overfit        >> Low bias & High Variance
# Underfit       >> High bias & Low Variance
# Balanced Model >> Low bias & Low Variance

# %% [markdown]
# ### 34.How to interpret a Q-Q plot in a Linear regression model?

# %% [raw]
# >> Q-Q plots are graphical tools that help you assess the validity of some assumptions in regression models, such as normality, linearity, and homoscedasticity.
#
# >>If the points lie on or close to a 45-degree line, it means that the data follow the reference distribution closely.
# >>If the points deviate from the line, it means that there are some differences between the data and the reference distribution.
#
# >>For example, if the points are curved, it means that the data are skewed or have heavy tails. If the points are scattered or have gaps, it means that the data have outliers or are multimodal.

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ### 35. What are the advantages and disadvantages of Linear Regression?

# %% [raw]
# >>Advantages<<
#   1. Simple model :
#   2. Computationally efficient :
#               - considerably lower time complexity compared to some of the other ML algorithms
#               - i.e. modeling speed of Linear regression is fast as it does not require complicated calculations and runs                       predictions fast when the amount of data is large.
#   3. Interpretability of the Output :
#               - The ability to determine the relative influence of one or more independent variable to the predicted values3.
#   4. Overfitting can be reduced by regularization :
#
# >>Disadvantages<<
#   1. Prone to underfitting :
#   2. Prone to noise and overfitting:
#               - If the number of observations are lesser than the number of features, Linear Regression should not be used,                     otherwise it may lead to overfit
#   3. Sensitive to outliers :
#   4. Limited use due to several Assumption :

# %% [markdown]
# ### 36. Explain Lasso Regression(L1 Regularization) in Details

# %% [raw]
#     “LASSO” >> Least Absolute Shrinkage and Selection Operator.
# >> Lasso regression is a type of linear regression that uses shrinkage.
# >> Lasso regression performs L1 regularization, which adds a penalty term to the absolute value of the magnitude of                coefficients.
# >> Some of the features in this technique are completely neglected for model evaluation...
# >> Hence, the Lasso regression can help us to reduce the overfitting in the model as well as the feature selection.
#
# >> tuning parameter, λ controls the strength of the L1 penalty. λ is basically the amount of shrinkage:
#
#             When λ = 0, no parameters are eliminated. The estimate is equal to the one found with linear regression.
#             -As λ increases, more and more coefficients are set to zero and eliminated (theoretically, when λ = ∞, all                        coefficients are eliminated).
#             -As λ increases, bias increases.
#             -As λ decreases, variance increases.

# %% [markdown]
# ### 37. Explain Ridge Regression(L2 Regularization) in Details

# %% [raw]
# >> Ridge regression is one of the types of linear regression in which a small amount of bias is introduced so that we can get better long-term predictions.
# >> Ridge regression is a regularization technique, which is used to reduce the complexity of the model.
# >> cost function is altered by adding the penalty term to it by multiplying with the lambda to the squared weight of each          individual feature.
# >> if there is high collinearity between the independent variables, so to solve such problems, Ridge regression can be used.
# >> It helps to solve the problems if we have more parameters than samples.

# %% [markdown]
# ![image.png](attachment:image.png)
